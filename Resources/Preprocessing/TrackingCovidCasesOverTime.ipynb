# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_totalcases=pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/cases_deaths/total_cases.csv")
df_newdeaths=pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/cases_deaths/new_deaths.csv")
df_totaldeaths=pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/cases_deaths/total_deaths.csv")
df_newcases=pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/cases_deaths/new_cases.csv")

# %%
data_newdeaths=df_newdeaths.copy()
data_newdeaths=data_newdeaths.fillna(0)

data_total_deaths=df_totaldeaths.copy()
data_total_deaths=data_total_deaths.fillna(0)

data_newcases=df_newcases.copy()
data_newcases=data_newcases.fillna(0)

data_totalcases=df_totalcases.copy()
data_totalcases=data_totalcases.fillna(0)

# %%
data_newdeaths = data_newdeaths.rename(columns={'World': 'World_newdeaths'})
data_newcases = data_newcases.rename(columns={'World': 'World_newcases'})

# %%
# data['World']=data['World'].astype(int)

# %%
# data[['date','World']].to_csv('World_Cases_daily.csv')

# %%
final=data_total_deaths.merge(data_newdeaths, how='inner', on='date')[['World','World_newdeaths','date']]
# final['cases']=final['World']-final['World_newdeaths']
final['check']=final['World']-final['World_newdeaths']

final_2=data_totalcases.merge(data_newcases, how='inner', on='date') [['World','World_newcases','date']]
final_2['check_2']=final_2['World']-final_2['World_newcases']

# %%
sns.lineplot(data=data_newdeaths, x="date", y="World_newdeaths")
# (totalcases- new cases) (totaldeaths- newdeaths)
# Out:
# <Axes: xlabel='date', ylabel='World_newdeaths'>

# %%
sns.lineplot(data=data_newcases, x="date", y="World_newcases")
# Out:
# <Axes: xlabel='date', ylabel='World_newcases'>

# %%
mydata=pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")

# %%
mydata=mydata.fillna(0)
mydata_1=mydata[['continent','total_cases']]
mydata_1=mydata_1.groupby(['continent']).sum()
mydata_1
# Out:
#                 total_cases
# continent
# 0              1.037433e+12
# Africa         7.885289e+09
# Asia           9.843925e+10
# Europe         1.083717e+11
# North America  6.322229e+10
# Oceania        4.206838e+09
# South America  3.826427e+10
